# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the reads seen 
refs_file = 'new_1_11_3.refs.txt'
oligos_read = []
with open(refs_file) as f:
    for line in f:
        oligos_read.append(int(line.rstrip('\n').split('_')[-1]))
oligos_read = np.array(oligos_read)

# %%
coverage = np.zeros(734,dtype=int)
for oligo in oligos_read:
    coverage[oligo] += 1

# %%
plt.plot(coverage)
plt.xlabel('oligo#')
plt.ylabel('coverage')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'coverage')

# %%
# now load gc biases of the oligos
path = '/raid/nanopore/shubham/20200214_nanopore_pool_data/data/oligo_files/oligos_2.fa'
gc_fraction = np.zeros(734)
oligo_num = 0
even = True
with open(path) as f:
    for line in f:
        if even:
            even = False
            continue
        even = True
        line = line.rstrip('\n')
        gc_fraction[oligo_num] = (line.count('G')+line.count('C'))/len(line)
        oligo_num += 1

# %%
plt.figure()
plt.plot(gc_fraction)

# %%
plt.hist(gc_fraction,histtype='step',bins=15)
# Out:
# (array([  6.,   4.,  10.,  12.,  47.,  74.,  72., 100.,  90., 105.,  79.,
#          55.,  42.,  26.,  12.]),
#  array([0.39520958, 0.40798403, 0.42075848, 0.43353293, 0.44630739,
#         0.45908184, 0.47185629, 0.48463074, 0.49740519, 0.51017964,
#         0.52295409, 0.53572854, 0.54850299, 0.56127745, 0.5740519 ,
#         0.58682635]),
#  <a list of 1 Patch objects>)

# %%
plt.hist(gc_fraction,histtype='step',bins=15,cumulative=True,density=True)
plt.grid()

# %%
plt.scatter(gc_fraction,coverage,alpha=0.1)
plt.xlabel('GC fraction')
plt.ylabel('Coverage')
# Out:
# Text(0, 0.5, 'Coverage')

# %%
import scipy.stats

# %%
scipy.stats.spearmanr(gc_fraction,coverage)
# Out:
# SpearmanrResult(correlation=-0.11141342230033305, pvalue=0.00250504079491605)

# %%
scipy.stats.spearmanr(np.abs(0.5-gc_fraction),coverage)
# Out:
# SpearmanrResult(correlation=0.0668241584944613, pvalue=0.07039410915189538)

# %%
scipy.stats.spearmanr(gc_fraction,coverage<500)
# Out:
# SpearmanrResult(correlation=0.11088292019435182, pvalue=0.0026275746886856785)

# %%
scipy.stats.pearsonr(gc_fraction,coverage)
# Out:
# (-0.18125202416899663, 7.685499216165507e-07)

# %%
# load the reads seen (second pool)
refs_file = 'new_2_11_3.refs.txt'
oligos_read_2 = []
with open(refs_file) as f:
    for line in f:
        oligos_read_2.append(int(line.rstrip('\n').split('_')[-1]))
oligos_read_2 = np.array(oligos_read_2)

# %%
coverage_2 = np.zeros(734,dtype=int)
for oligo in oligos_read_2:
    coverage_2[oligo] += 1

# %%
plt.scatter(coverage,coverage_2)
plt.xlabel('Coverage in sequencing run 1')
plt.ylabel('Coverage in sequencing run 2')
# Out:
# Text(0, 0.5, 'Coverage in sequencing run 2')

# %%
# now load gc biases of the oligos (old pool)
path = '/raid/nanopore/shubham/20190629_nanopore_data/oligo_files/oligos_4.fa'
gc_fraction = np.zeros(815)
oligo_num = 0
even = True
with open(path) as f:
    for line in f:
        if even:
            even = False
            continue
        even = True
        line = line.rstrip('\n')
        gc_fraction[oligo_num] = (line.count('G')+line.count('C'))/len(line)
        oligo_num += 1

# %%
plt.hist(gc_fraction,histtype='step',bins=15)
# Out:
# (array([  8.,  16.,  23.,  45.,  63., 106., 115., 103., 127.,  77.,  60.,
#          39.,  19.,   9.,   5.]),
#  array([0.43113772, 0.44391218, 0.45668663, 0.46946108, 0.48223553,
#         0.49500998, 0.50778443, 0.52055888, 0.53333333, 0.54610778,
#         0.55888224, 0.57165669, 0.58443114, 0.59720559, 0.60998004,
#         0.62275449]),
#  <a list of 1 Patch objects>)

# %%
# now load gc biases of the oligos (oligo 9)
path = '/raid/nanopore/shubham/20200214_nanopore_pool_data/data/oligo_files/oligos_9.fa'
gc_fraction = np.zeros(825)
oligo_num = 0
even = True
with open(path) as f:
    for line in f:
        if even:
            even = False
            continue
        even = True
        line = line.rstrip('\n')
        gc_fraction[oligo_num] = (line.count('G')+line.count('C'))/len(line)
        oligo_num += 1

# %%
plt.hist(gc_fraction,histtype='step',bins=15)
# Out:
# (array([  2.,   5.,  13.,  22.,  33.,  66., 116., 205., 114.,  97.,  63.,
#          47.,  22.,  13.,   7.]),
#  array([0.38607595, 0.39957806, 0.41308017, 0.42658228, 0.44008439,
#         0.4535865 , 0.46708861, 0.48059072, 0.49409283, 0.50759494,
#         0.52109705, 0.53459916, 0.54810127, 0.56160338, 0.57510549,
#         0.58860759]),
#  <a list of 1 Patch objects>)

# %%
# now load gc biases of the oligos (oligo 9)
path = '/raid/nanopore/shubham/20200214_nanopore_pool_data/data/oligo_files/oligos_12.fa'
gc_fraction = np.zeros(660)
oligo_num = 0
even = True
with open(path) as f:
    for line in f:
        if even:
            even = False
            continue
        even = True
        line = line.rstrip('\n')
        gc_fraction[oligo_num] = (line.count('G')+line.count('C'))/len(line)
        oligo_num += 1

# %%
plt.hist(gc_fraction,histtype='step',bins=15)
# Out:
# (array([  4.,   5.,  19.,  33.,  47.,  67., 130.,  82.,  63.,  75.,  94.,
#          13.,  24.,   1.,   3.]),
#  array([0.4011976 , 0.41317365, 0.4251497 , 0.43712575, 0.4491018 ,
#         0.46107784, 0.47305389, 0.48502994, 0.49700599, 0.50898204,
#         0.52095808, 0.53293413, 0.54491018, 0.55688623, 0.56886228,
#         0.58083832]),
#  <a list of 1 Patch objects>)
